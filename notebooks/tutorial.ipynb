# %% [markdown]
# # Multivariate Anomaly Detection Tutorial
#
# This notebook demonstrates how to use the multivariate anomaly detection toolkit for various scenarios.
#
# ## Table of Contents
# 1. [Setup and Imports](#setup)
# 2. [Data Generation](#data-generation)
# 3. [Autoencoder Model](#autoencoder)
# 4. [Isolation Forest Model](#isolation-forest)
# 5. [Time Series Analysis](#time-series)
# 6. [Model Comparison](#model-comparison)
# 7. [Visualization](#visualization)

# %%
import sys
import os
sys.path.append('src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

from src.app import AnomalyDetectionApp
from src.data_utils import TimeSeriesGenerator, DataPreprocessor
from src.models import AnomalyDetector
from src.visualization import AnomalyVisualizer
from src.config import Config

# Set up plotting
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')

print("Setup complete!")
